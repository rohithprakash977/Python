# %%
class Animal:
  def eat(self):
    print("Animal is eating")
class Dog(Animal):
  def bark(self):
    print("Dog is barking")
dog = Dog()
dog.eat()
dog.bark()
# Out:
# Animal is eating
# Dog is barking

# %%
class Ride:
    def fare(self):
        print("Fare: ₹100")
class LuxuryRide(Ride):
    def fare(self):
        print("Fare: ₹300")
luxury = LuxuryRide()
luxury.fare()
normal = Ride()
normal.fare()

# %%
class Course:
    def course_fee(self):
        print("Course Fee: 5000/-")
class AdvancedCourse(Course):
    def course_fee(self):
        print("Course Fee: 12000/-")
advanced = AdvancedCourse()
advanced.course_fee()
basic = Course()
basic.course_fee()
# Out:
# Course Fee: 12000/-
# Course Fee: 5000/-

# %%
class Ticket:
    def price(self):
        print("Ticket Price: ₹150")
class VIPTicket(Ticket):
    def price(self):
        print("Ticket Price: ₹500")
ticket = VIPTicket()
ticket.price()
# Out:
# Ticket Price: ₹500

# %%
class Customer:
    def delivery_charge(self):
        print("Delivery Charge: ₹50")
class PrimeCustomer(Customer):
    def delivery_charge(self):
        print("Delivery Charge: ₹20")
customer = PrimeCustomer()
customer.delivery_charge()
# Out:
# Delivery Charge: ₹20

# %%
class Employee:
    def work_hours(self):
        print("Employee works 8 hours a day")
class Intern(Employee):
    def work_hours(self):
        print("Intern works 6 hours a day")
intern = Intern()
intern.work_hours()
# Out:
# Intern works 6 hours a day

# %%
class Candidate:
    def __init__(self, name, skills):
        self.name = name
        self.skills = set(skills)

class Job:
    def __init__(self, title, req_skills):
        self.title = title
        self.req_skills = set(req_skills)

c = Candidate("Rahul", ["Python", "SQL"])
job = Job("Developer", ["Python", "SQL"])

scores = {"Rahul": 85}

if job.req_skills.issubset(c.skills) and scores["Rahul"] >= 70:
    print("Selected")
else:
    print("Rejected")
# Out:
# Selected

# %%
class Bankaccount:
  def __init__(self, name, acc_no, pin):
    self._name = name
    self._acc_no = acc_no
    self._pin = pin
    print("account created")

  def get_name(self):
    print(self._name)

  def get_acc_no(self):
    print(self._acc_no)

  def get_pin(self):
    print(self._pin)

b1 = Bankaccount('scott', 123456789, 1234)
b1.get_name()
b1.get_acc_no()
b1.get_pin()
print(b1)
# Out:
# account created
# scott
# 123456789
# 1234
# ...

# %%
class Student():
  def __init__(self):
    print("Student Object is created...!")
s1=Student()
s2=Student()
# Out:
# Student Object is created...!
# Student Object is created...!

# %%
class product:
  def __init__(self,name,price):
    print("Product obect is created...!")
    self.name=name
    self.price=price
    print("----------")
P1=product("phone",2000)
print(f"name={P1.name}")
print(f"price={P1.price}")
P2=product("laptop",5000)
print(f"name={P2.name}")
print(f"price={P2.price}")
P3=product("mouse",100)
print(f"name={P3.name}")
print(f"price={P3.price}")
P4=product("keyboard",200)
print(f"name={P4.name}")
print(f"price={P4.price}")
P5=product("monitor",300)
print(f"name={P5.name}")
print(f"price={P5.price}")
# Out:
# Product obect is created...!
# ----------
# name=phone
# price=2000
# Product obect is created...!
# ----------
# name=laptop
# price=5000
# Product obect is created...!
# ----------
# name=mouse
# price=100
# Product obect is created...!
# ----------
# name=keyboard
# price=200
# Product obect is created...!
# ----------
# name=monitor
# price=300

# %%
class Student():
  def __init__(self, name, age):
    print("Student Object is created...!")
    self.name = name
    self.age = age

  def details(self):
    print("---------")
    print(f"name is {self.name}")
    print(f"age is {self.age}")
s1=Student('scott',23)
s1.details()
s2=Student('john',25)
s2.details()
s3=Student('mark',27)
s3.details()
s4=Student('tom',29)
s4.details()
s5=Student('jerry',31)
s5.details()
# Out:
# Student Object is created...!
# ---------
# name is scott
# age is 23
# Student Object is created...!
# ---------
# name is john
# age is 25
# Student Object is created...!
# ---------
# name is mark
# age is 27
# Student Object is created...!
# ---------
# name is tom
# age is 29
# Student Object is created...!
# ---------
# name is jerry
# age is 31

# %%
class Mobile:
  def __init__(self,name,color,price):
    self.brand=name # Changed 'brand' to 'name'
    self.color=color
    self.price=price
  def details(self):
    print(f"name:{self.brand}") # Changed 'self.name' to 'self.brand'
    print(f"color:{self.color}")
    print(f"price:{self.price}")
M1=Mobile("samsung","black",50000)
M1.details()
M2=Mobile("iphone","white",60000)
M2.details()
M3=Mobile("realme","blue",20000)
M3.details()
M4=Mobile("oppo","red",30000)
M4.details()
M5=Mobile("vivo","green",40000)
M5.details()
# Out:
# name:samsung
# color:black
# price:50000
# name:iphone
# color:white
# price:60000
# name:realme
# color:blue
# price:20000
# name:oppo
# color:red
# price:30000
# name:vivo
# color:green
# price:40000

# %%
class Employee():
    def __init__(self,emp_name,emp_id,emp_salary,emp_department,emp_job):
        self.emp_name=emp_name
        self.emp_id=emp_id
        self.emp_salary=emp_salary
        self.emp_department=emp_department
        self.emp_job=emp_job
def show_employeedetails(self):
    print("Employee name is:",self.emp_name)
    print("Employee id is:",self.emp_id)
    print("Employee salary is:",self.emp_salary)
    print("Employee department is:",self.emp_department)
    print("Employee job is:",self.emp_job)
emp1=Employee("rohit",21,60000,"HR","Manager")
show_employeedetails(emp1)
emp2=Employee("priya",22,10000,"IT","developer")
show_employeedetails(emp2)
emp3=Employee("rohit",32,30000,"finance","analyst")
show_employeedetails(emp3)
emp4=Employee("rohit",18,20000,"HR","Manager")
show_employeedetails(emp4)
emp5=Employee("rohit",18,20000,"HR","Manager")
show_employeedetails(emp5)
# Out:
# Employee name is: rohit
# Employee id is: 21
# Employee salary is: 60000
# Employee department is: HR
# Employee job is: Manager
# Employee name is: priya
# Employee id is: 22
# Employee salary is: 10000
# Employee department is: IT
# Employee job is: developer
# Employee name is: rohit
# Employee id is: 32
# Employee salary is: 30000
# Employee department is: finance
# Employee job is: analyst
# Employee name is: rohit
# Employee id is: 18
# Employee salary is: 20000
# Employee department is: HR
# Employee job is: Manager
# Employee name is: rohit
# Employee id is: 18
# Employee salary is: 20000
# Employee department is: HR
# Employee job is: Manager

# %%
class customer:
    def __init__(self):
        pass
    def set_id(self,id):
        self.id=id
    def set_name(self,name):
        self.name=name
    def set_age(self,age):
        self.age=age
    def get_id(self):
        return self.id
    def get_name(self):
        return self.name
    def get_age(self):
        return self.age
C1=customer()
C1.set_id(101)
C1.set_name("Irfan")
C1.set_age(25)
print("Customer Details")
print("Customer id:",C1.get_id())
print("Customer name:",C1.get_name())
print("Customer age:",C1.get_age())
C2=customer()
C2.set_id(102)
C2.set_name("Ravi")
C2.set_age(30)
print("Customer Details")
print("Customer id:",C2.get_id())
print("Customer name:",C2.get_name())
print("Customer age:",C2.get_age())
# Out:
# Customer Details
# Customer id: 101
# Customer name: Irfan
# Customer age: 25
# Customer Details
# Customer id: 102
# Customer name: Ravi
# Customer age: 30

# %%
class Mobile:
  @classmethod
  def show_model(cls):
    print("RealMe X")
realme=Mobile()
Mobile.show_model()
class Mobile:
  @staticmethod
  def show_model():
    print("RealMe X")
realme=Mobile()
Mobile.show_model()
# Out:
# RealMe X
# RealMe X

# %%
class Veichle:
  def __init__(self,b,p,c,s):
    self.b=b
    self.p=p
    self.c=c
    self.s=s
    print('Veichle class Constructor')
class Bike(Veichle):
  def __init__(self,b,p,c,s,g,m):
    super().__init__(b,p,c,s)
    self.g=g
    self.m=m
    print('Bike class Constructor')
b1=Bike('Tata',25000,'black',2,3,45)
# Out:
# Veichle class Constructor
# Bike class Constructor

# %%
class engineer:
  def __init__(self):
    pass
  def work(self):
    print("Engineer is working...!")
class SoftwareEngineer(engineer):
  pass
